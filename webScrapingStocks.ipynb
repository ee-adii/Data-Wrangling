# %% [markdown]
# #**Webscraping the Indian Stock Market data**
# *data present at* : https://www.tradingview.com/markets/stocks-india/sectorandindustry-sector/

# %%
import requests 
import pandas as pd
from bs4 import BeautifulSoup as bs

# %% [markdown]
# #Pipeline for Sector-wise Dataset

# %%
url_1 = 'https://www.tradingview.com/markets/stocks-india/sectorandindustry-sector/'
r = requests.get(url_1)   
htmlContent = r.content    ## geting content fron given url
soup_1 =  bs(htmlContent , 'html.parser')
direct_df = pd.read_html(url_1)   ## this gives the structure of dataframe look ugly!!!
direct_df = pd.read_html(str(soup_1))  ## this gives a better dataframe
sectors = list(direct_df[0]['Sector'])

def get_sector_data():
  frames = []
  sec = []
  for i in range(0,len(sectors)):
    sector_df = None
    temp = ' ' in sectors[i]
    if temp == True:
     s  = sectors[i]
     s  = s[:s.index(" ")]+'-'+s[s.index(" ")+1:]
     url = 'https://www.tradingview.com/markets/stocks-india/sectorandindustry-sector/'+s.lower()+'/'
     r = requests.get(url)   
     htmlContent = r.content    ## geting content fron given url
     soup =  bs(htmlContent , 'html.parser') 
     sector_df = pd.read_html(str(soup))  ## this gives a better dataframe
     sector_df = sector_df[0]
     for k in range(0,sector_df.shape[0]):
       sec.append(sectors[i])
     frames.append(sector_df)
    else:
     url = 'https://www.tradingview.com/markets/stocks-india/sectorandindustry-sector/'+sectors[i].lower()+'/'
     r = requests.get(url)   
     htmlContent = r.content    ## geting content fron given url
     soup =  bs(htmlContent , 'html.parser') 
     sector_df = pd.read_html(str(soup))  ## this gives a better dataframe
     sector_df = sector_df[0]
     for k in range(0,sector_df.shape[0]):
       sec.append(sectors[i])
     frames.append(sector_df)
  result = pd.concat(frames)
  result['Sector'] = sec
  return result

# %%
df_sector = get_sector_data()
df_sector
# Out:
#                             Ticker       Price Change % 1D  Change 1D  \
# 0       33RDROCK3RD ROCK MULTIMEDI   61.20 INR      −5.26%  −3.40 INR
# 1    44THDIMFOURTH DIMENSION SOL L   36.35 INR       1.82%   0.65 INR
# 2            AAARVIAARVI ENCON LTD  116.60 INR      −3.28%  −3.95 INR
# 3       AADLARCHIDPLY DECOR LIMTED   59.30 INR       2.42%   1.40 INR
# 4   AADROITINFOADROIT INFOTECH LTD   20.60 INR      −2.83%  −0.60 INR
# ..                             ...         ...         ...        ...
# 37       SWANENERGYSWAN ENERGY LTD  250.80 INR      −2.22%  −5.70 INR
# 38      TATAPOWERTATA POWER CO LTD  202.30 INR       0.50%   1.00 INR
# 39     TTEXINFRATEXMACO INFRA & HO   52.65 INR      −2.41%  −1.30 INR
# 40         TORNTPOWERTORRENT POWER  496.70 INR      −1.16%  −5.85 INR
# 41          UUJAASUJAAS ENERGY LTD    2.30 INR       4.55%   0.10 INR
#
#    Technical Rating 1D Volume 1D Volume * Price 1D    Market cap P/E(TTM)  \
# 0          Strong Sell      5.2K           318.24K             —        —
# 1           Strong Buy  299.892K           10.901M             —        —
# 2                 Sell    12.66K            1.476M    1.782B INR    12.99
# 3                 Sell       143             8.48K             —        —
# 4                 Sell   27.402K          564.481K  388.182M INR     8.68
# ..                 ...       ...               ...           ...      ...
# 37                Sell  152.106K           38.148M    67.84B INR        —
# 38                Sell    5.213M            1.055B  643.222B INR    21.02
# 39         Strong Sell    12.17K          640.751K    6.868B INR   243.02
# 40                 Buy  260.551K          129.416M  241.366B INR    20.46
# 41                Sell   70.337K          161.775K  446.647M INR        —
#
#      EPS(TTM) Employees               Sector
# 0           —         —  Commercial Services
# 1           —         —  Commercial Services
# 2    9.28 INR    5.541K  Commercial Services
# 3           —         —  Commercial Services
# 4    2.44 INR         9  Commercial Services
# ..        ...       ...                  ...
# 37  −2.30 INR       447            Utilities
# 38   9.58 INR   65.947K            Utilities
# 39   0.22 INR        34            Utilities
# 40  24.56 INR   18.324K            Utilities
# 41  −1.98 INR        85            Utilities
#
# [1413 rows x 12 columns]

# %% [markdown]
# #Pipeline for Industry-wise Dataset

# %%
url_2 = 'https://www.tradingview.com/markets/stocks-india/sectorandindustry-industry/'
r = requests.get(url_2)   
htmlContent = r.content    ## geting content fron given url
soup_2 =  bs(htmlContent , 'html.parser')
direct_df = pd.read_html(url_2)   ## this gives the structure of dataframe look ugly!!!
direct_df = pd.read_html(str(soup_2))  ## this gives a better dataframe
industries = list(direct_df[0]['Industry'])

def removeSpcl(arr):
  s = [' & ',': ','/',' ']
  for i in range(0,len(arr)):
    for j in range(0,len(s)):
      if s[j] in arr[i]:
        arr[i] = arr[i].replace(s[j],'-')
    arr[i] = arr[i].lower()
removeSpcl(industries)

#fetching dataset of Industry page
url_3 = 'https://www.tradingview.com/markets/stocks-india/sectorandindustry-industry/'
r = requests.get(url_3)   
htmlContent = r.content    ## geting content fron given url
soup_3 =  bs(htmlContent , 'html.parser')
direct_df = pd.read_html(url_3)   ## this gives the structure of dataframe look ugly!!!
direct_df = pd.read_html(str(soup_3))  ## this gives a better dataframe
direct_df =direct_df[0]
sec_for_indusDF = list(direct_df['Sector']) # this gives the sector of a stock 
len(sec_for_indusDF)

def get_industry_data():
  frames = []
  industry = []
  sec_for_indus =[] #stores the sector of a industry
  for i in range(0,len(industries)):
    indus_df = None
    temp = ' ' in industries[i]
    if temp == True:
     s  = industries[i]
     s  = s[:s.index(" ")]+'-'+s[s.index(" ")+1:]
     url = 'https://www.tradingview.com/markets/stocks-india/sectorandindustry-industry/'+s.lower()+'/'
     r = requests.get(url)   
     htmlContent = r.content    ## geting content fron given url
     soup =  bs(htmlContent , 'html.parser') 
     indus_df = pd.read_html(str(soup))  ## this gives a better dataframe
     indus_df = indus_df[0]
     for k in range(0,indus_df.shape[0]):
       industry.append(industries[i])
       sec_for_indus.append(sec_for_indusDF[i])
     frames.append(indus_df)
    else:
     url = 'https://www.tradingview.com/markets/stocks-india/sectorandindustry-industry/'+industries[i].lower()+'/'
     r = requests.get(url)   
     htmlContent = r.content    ## geting content fron given url
     soup =  bs(htmlContent , 'html.parser') 
     indus_df = pd.read_html(str(soup))  ## this gives a better dataframe
     indus_df = indus_df[0]
     for k in range(0,indus_df.shape[0]):
       industry.append(industries[i])
       sec_for_indus.append(sec_for_indusDF[i])
     frames.append(indus_df)
  result = pd.concat(frames)
  result['Industry'] = industry #adding industry column from industry list to final dataset
  result['Sector'] = sec_for_indus #adding sector column from sec_for_indus list to final dataset
  return result

# %%
df_indus = get_industry_data()

# %%
df_indus
# Out:
#                            Ticker       Price Change % 1D  Change 1D  \
# 0      33RDROCK3RD ROCK MULTIMEDI   61.20 INR      −5.26%  −3.40 INR
# 1     NNOIDATOLLNOIDA TOLL BRIDGE    6.95 INR       0.72%   0.05 INR
# 2      PPRESSMNPRESSMAN ADVERTISI   68.35 INR       4.99%   3.25 INR
# 3      SSPCENETSPACENET ENTERPRIS   19.05 INR       2.70%   0.50 INR
# 4   VVERTOZVERTOZ ADVERTISING LTD  215.95 INR       3.77%   7.85 INR
# ..                            ...         ...         ...        ...
# 13     SSATIASATIA INDUSTRIES LTD  117.00 INR      −0.43%  −0.50 INR
# 14  SSESHAPAPERSESHASAYEE PAPER&B  250.20 INR      −1.69%  −4.30 INR
# 15  SSHREYANINDSHREYANS INDUSTRIE  151.80 INR      −0.56%  −0.85 INR
# 16     SSTARPAPERSTAR PAPER MILLS  163.95 INR       0.52%   0.85 INR
# 17        TTNPLTAMIL NADU NEWSPRI  217.45 INR      −0.53%  −1.15 INR
#
#    Technical Rating 1D Volume 1D Volume * Price 1D   Market cap P/E(TTM)  \
# 0          Strong Sell      5.2K           318.24K            —        —
# 1                 Sell     75.6K           525.42K   1.281B INR        —
# 2           Strong Buy   25.312K             1.73M   1.531B INR    37.11
# 3                 Sell   75.949K            1.447M            —        —
# 4                  Buy   43.848K            9.469M   2.491B INR    28.41
# ..                 ...       ...               ...          ...      ...
# 13         Strong Sell    69.11K            8.086M   11.74B INR     6.70
# 14         Strong Sell   18.785K              4.7M  16.073B INR     6.69
# 15                Sell    6.635K            1.007M     2.1B INR     4.36
# 16                Sell   21.758K            3.567M   2.545B INR     3.80
# 17                Sell  281.158K           61.138M  15.136B INR     4.92
#
#      EPS(TTM) Employees                        Industry               Sector
# 0           —         —  advertising-marketing-services  Commercial Services
# 1   −1.86 INR         3  advertising-marketing-services  Commercial Services
# 2    1.75 INR        18  advertising-marketing-services  Commercial Services
# 3           —         —  advertising-marketing-services  Commercial Services
# 4    7.33 INR       113  advertising-marketing-services  Commercial Services
# ..        ...       ...                             ...                  ...
# 13  17.55 INR    2.012K                      pulp-paper   Process Industries
# 14  38.07 INR    2.555K                      pulp-paper   Process Industries
# 15  35.05 INR    1.299K                      pulp-paper   Process Industries
# 16  42.94 INR       371                      pulp-paper   Process Industries
# 17  44.43 INR    2.371K                      pulp-paper   Process Industries
#
# [1782 rows x 13 columns]

# %%
arr_indus  = list(df_indus['Ticker'])

# %%
df_indus.to_csv("Industries_Data.csv")

# %%
df_sector.to_csv("sector_data.csv")

# %%
df1 = pd.read_excel("/content/drive/MyDrive/MCAP31122022_0.xlsx")

# %%
arr1 = list(df1['Symbol'])
len(arr1)
# Out:
# 2114

# %%
df2  = pd.read_csv("/content/drive/MyDrive/BSE.csv")

# %%
arr2 = list(df2['Issuer Name'])
len(arr2)
# Out:
# 9250

# %%
final_list = (arr1 + arr2)
len(final_list)
# Out:
# 11364

# %%
final_list.sort
print((final_list))
# Out:
# ['RELIANCE', 'TCS', 'HDFCBANK', 'INFY', 'ICICIBANK', 'HINDUNILVR', 'SBIN', 'HDFC', 'BHARTIARTL', 'ADANIENT', 'LICI', 'ITC', 'ATGL', 'BAJFINANCE', 'KOTAKBANK', 'ADANIGREEN', 'ASIANPAINT', 'LT', 'ADANITRANS', 'AXISBANK', 'HCLTECH', 'DMART', 'MARUTI', 'BAJAJFINSV', 'SUNPHARMA', 'TITAN', 'WIPRO', 'ULTRACEMCO', 'JSWSTEEL', 'ONGC', 'ADANIPORTS', 'NTPC', 'M&M', 'POWERGRID', 'COALINDIA', 'TATASTEEL', 'HINDZINC', 'PIDILITIND', 'LTIM', 'TATAMOTORS', 'SBILIFE', 'HDFCLIFE', 'ADANIPOWER', 'VEDL', 'GRASIM', 'IOC', 'HINDALCO', 'AMBUJACEM', 'BRITANNIA', 'BAJAJ-AUTO', 'SIEMENS', 'DABUR', 'TECHM', 'BANKBARODA', 'INDUSINDBK', 'DLF', 'DIVISLAB', 'GODREJCP', 'EICHERMOT', 'CIPLA', 'VBL', 'HAL', 'SHREECEM', 'AWL', 'INDIGO', 'SBICARD', 'BEL', 'BPCL', 'TATACONSUM', 'DRREDDY', 'HAVELLS', 'SRF', 'TATAPOWER', 'MARICO', 'ICICIPRULI', 'APOLLOHOSP', 'BAJAJHLDNG', 'MCDOWELL-N', 'GAIL', 'PNB', 'ICICIGI', 'IOB', 'CANBK', 'CHOLAFIN', 'YESBANK', 'JINDALSTEL', 'IDBI', 'ABB', 'BERGEPAINT', 'UNIONBANK', 'HEROMOTOCO', 'UPL', 'TIINDIA', 'LODHA', 'TORNTPHARM', 'PIIND', 'TVSMOTOR', 'INDUSTOWER', 'IRCTC', 'BOSCHLTD', 'NAUKRI', 'ZOMATO', 'MOTHERSON', 'TRENT', 'PAGEIND', 'JSWENERGY', 'PGHH', 'HDFCAMC', 'ACC', 'INDHOTEL', 'CONCOR', 'UBL', 'NYKAA', 'AUBANK', 'PATANJALI', 'SCHAEFFLER', 'MUTHOOTFIN', 'MAXHEALTH', 'IRFC', 'ZYDUSLIFE', 'ASHOKLEY', 'COLPAL', 'CGPOWER', 'BALKRISIND', 'BHARATFORG', 'NHPC', 'SOLARINDS', 'ASTRAL', 'TATAELXSI', 'LTTS', 'POLYCAB', 'CUMMINSIND', 'BANDHANBNK', 'UCOBANK', 'MRF', 'PFC', 'SHRIRAMFIN', 'MPHASIS', 'HONAUT', 'IDFCFIRSTB', 'TATACOMM', 'ABCAPITAL', 'BANKINDIA', 'NMDC', 'ALKEM', 'INDIANB', 'DALBHARAT', 'PAYTM', 'FLUOROCHEM', 'SAIL', 'GODREJPROP', 'JUBLFOOD', 'GUJGASLTD', 'LUPIN', 'HINDPETRO', 'STARHEALTH', 'MANYAVAR', 'PETRONET', 'OBEROIRLTY', 'BIOCON', 'GICRE', 'SUPREMEIND', 'RECLTD', 'APLAPOLLO', 'UNOMINDA', 'PERSISTENT', 'FEDERALBNK', 'LINDEINDIA', 'M&MFIN', 'IGL', 'ESCORTS', 'CENTRALBK', 'BHEL', 'ABFRL', 'DEEPAKNTR', 'VOLTAS', 'OFSS', 'COROMANDEL', 'GLAND', 'MSUMI', 'AUROPHARMA', 'SUNDARMFIN', 'PHOENIXLTD', 'IDEA', '3MINDIA', 'SONACOMS', 'ATUL', 'SUMICHEM', 'AIAENG', 'FACT', 'DELHIVERY', 'METROBRAND', 'GMRINFRA', 'TATACHEM', 'COFORGE', 'KANSAINER', 'TORNTPOWER', 'POONAWALLA', 'SYNGENE', 'THERMAX', 'MFSL', 'TIMKEN', 'DIXON', 'ZEEL', 'PSB', 'LICHSGFIN', 'RELAXO', 'OIL', 'JKCEMENT', 'CRISIL', 'GLAXO', 'SKFINDIA', 'AARTIIND', 'DEVYANI', 'L&TFH', 'RAJESHEXPO', 'FORTIS', 'CROMPTON', 'IPCALAB', 'BATAINDIA', 'NIACL', 'APOLLOTYRE', 'MAHABANK', 'VINATIORGA', 'SUNDRMFAST', 'PFIZER', 'HATSUN', 'POLICYBZR', 'LAURUSLABS', 'NAVINFLUOR', 'PEL', 'GRINDWELL', 'ENDURANCE', 'KPITTECH', 'SUNTV', 'WHIRLPOOL', 'LALPATHLAB', 'EMAMILTD', 'PRESTIGE', 'KAJARIACER', 'BLUEDART', 'IIFL', 'TTML', 'FIVESTAR', 'KPRMILL', 'FINEORG', 'IRB', 'TRIDENT', 'BDL', 'ZFCVINDIA', 'CARBORUNIV', 'RAMCOCEM', 'GILLETTE', 'ISEC', 'MAZDOCK', 'CLEAN', 'IIFLWAM', 'NH', 'AJANTPHARM', 'NAM-INDIA', 'EXIDEIND', 'APTUS', 'JBCHEPHARM', 'GSPL', 'NATIONALUM', 'AAVAS', 'GODREJIND', 'AFFLE', 'CREDITACC', 'RVNL', 'POWERINDIA', 'REDINGTON', 'DCMSHRIRAM', 'BAJAJELEC', 'KIOCL', 'RATNAMANI', 'PPLPHARMA', 'ALKYLAMINE', 'RADICO', 'RHIM', 'SANOFI', 'SJVN', 'CUB', 'ELGIEQUIP', 'INDIAMART', 'CGCL', 'KEI', 'ABSLAMC', 'MAHINDCIE', 'NUVOCO', 'KALYANKJIL', 'IDFC', 'LAXMIMACH', 'HAPPSTMNDS', 'CHAMBLFERT', 'ASAHIINDIA', 'KEC', 'SFL', 'SUVENPHAR', 'CAMPUS', 'IEX', 'MEDANTA', 'JSL', 'KIMS', 'RENUKA', 'BASF', 'AEGISCHEM', 'CASTROLIND', 'GLENMARK', 'NLCINDIA', 'CDSL', 'FINPIPE', 'BLUESTARCO', 'ASTERDM', 'CENTURYPLY', 'VGUARD', 'APLLTD', 'TTKPRESTIG', 'EIHOTEL', 'GRINFRA', 'ANGELONE', 'UTIAMC', 'CAMS', 'BIKAJI', 'RBLBANK', 'BRIGADE', 'TATAINVEST', 'SUZLON', 'HINDCOPPER', 'PVR', 'AETHER', 'HUDCO', 'JSLHISAR', 'CHOLAHLDNG', 'GODFRYPHLP', 'NATCOPHARM', 'HFCL', 'MOTILALOFS', 'CESC', 'SUNCLAYLTD', 'AKZOINDIA', 'EIDPARRY', 'ALLCARGO', 'ITI', 'MRPL', 'MANAPPURAM', 'RAYMOND', 'AMARAJABAT', 'TANLA', 'JKLAKSHMI', 'ZYDUSWELL', 'GESHIP', 'VTL', 'VIPIND', 'KRBL', 'EASEMYTRIP', 'KARURVYSYA', 'DEEPAKFERT', 'GODREJAGRO', 'PNBHOUSING', 'CY ...

# %%
arr_indus.sort
print(len(arr_indus))
# Out:
# 1782

# %%
def getMatch(arr1 , arr2 ):  #arr1>arr2
  ll =[]
  for i in range(0,len(arr2)):
    for j in range(0,len(arr1)):
      if str(arr1[j]) in str(arr2[i]):
        ll.append(arr1[j])
        break
        
  return ll

# %%
ll
# Out:
# ['LT',
#  'NOIDATOLL',
#  'TI',
#  'ACE',
#  'LT',
#  'LT',
#  'BEL',
#  'HAL',
#  'KRISHNADEF',
#  'LT',
#  'PARAS',
#  'LT',
#  'LT',
#  'ATFL',
#  'AVADHSUGAR',
#  'AVANTIFEED',
#  'LT',
#  'LT',
#  'BAJAJHIND',
#  'BALRAMCHIN',
#  'BANARISUG',
#  'LT',
#  'LT',
#  'DALMIASUG',
#  'LT',
#  'LT',
#  'DHAMPURSUG',
#  'DHARSUGAR',
#  'TI',
#  'DWARKESH',
#  'LT',
#  'GODREJIND',
#  'OIL',
#  'LT',
#  'LT',
#  'HARRMALAYA',
#  'JAYAGROGN',
#  'JAYSREETEA',
#  'LT',
#  'KCP',
#  'LT',
#  'KNAGRI',
#  'KOHINOOR',
#  'KOTARISUG',
#  'LT',
#  'KRISHIVAL',
#  'LT',
#  'KSCL',
#  'MAGADSUGAR',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'NATHBIOGEN',
#  'NKIND',
#  'OSWALSEEDS',
#  'LT',
#  'PKTEA',
#  'PONNIERODE',
#  'RAJSREESUG',
#  'RAJVIR',
#  'LT',
#  'RENUKA',
#  'LT',
#  'TI',
#  'SANWARIA',
#  'LT',
#  'LT',
#  'HAL',
#  'SKMEGGPROD',
#  'LT',
#  'LT',
#  'TATACOFFEE',
#  'TRIVENI',
#  'UGARSUGAR',
#  'USASEEDS',
#  'UTTAMSUGAR',
#  'VENKEYS',
#  'LT',
#  'RBA',
#  'LT',
#  'LT',
#  'TI',
#  'ASPINWALL',
#  'LT',
#  'BLUEDART',
#  'LT',
#  'TI',
#  'LT',
#  'FMNL',
#  'PPL',
#  'TI',
#  'TI',
#  'MAHLOG',
#  'SCI',
#  'TI',
#  'LT',
#  'TI',
#  'LT',
#  'INDIGO',
#  'JETAIRWAYS',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'POWERGRID',
#  'LT',
#  'EUROBOND',
#  'LT',
#  'NATIONALUM',
#  'ORIENTABRA',
#  'PRECISION',
#  'LT',
#  'ABCOTS',
#  'BATAINDIA',
#  'BHANDARI',
#  'LT',
#  'CANTABIL',
#  'CELEBRITY',
#  'DOLLAR',
#  'LT',
#  'LT',
#  'GOKEX',
#  'RAIN',
#  'LT',
#  'LT',
#  'LT',
#  'KKCL',
#  'LT',
#  'LT',
#  'LIBERTSHOE',
#  'LOVABLE',
#  'LT',
#  'LT',
#  'MIRZAINT',
#  'MONTECARLO',
#  'LT',
#  'LT',
#  'PGIL',
#  'LT',
#  'RELAXO',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'TCNSBRANDS',
#  'THOMASCOTT',
#  'VARDHACRLC',
#  'LT',
#  'LT',
#  'ZODIACLOTH',
#  'ABFRL',
#  'LT',
#  'LT',
#  'FLFL',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'ALICON',
#  'TI',
#  'AUTOAXLES',
#  'AUTOIND',
#  'LT',
#  'CUMMINSIND',
#  'LT',
#  'EXIDEIND',
#  'LT',
#  'GABRIEL',
#  'LT',
#  'HINDCOMPOS',
#  'HITECH',
#  'IGARASHI',
#  'INDNIPPON',
#  'JAMNAAUTO',
#  'LT',
#  'KALYANIFRG',
#  'LUMAXIND',
#  'LUMAXTECH',
#  'MAHINDCIE',
#  'METALFORGE',
#  'LT',
#  'LT',
#  'MOTHERSON',
#  'MUNJALAU',
#  'MUNJALSHOW',
#  'LT',
#  'NRBBEARING',
#  'LT',
#  'PAVNAIND',
#  'LT',
#  'CAMS',
#  'LT',
#  'ITI',
#  'LT',
#  'RANEENGINE',
#  'LT',
#  'RBL',
#  'REMSONSIND',
#  'RICOAUTO',
#  'LT',
#  'LT',
#  'TI',
#  'SHANTIGEAR',
#  'SHARDAMOTR',
#  'LT',
#  'SHRIPISTON',
#  'LT',
#  'LT',
#  'SONACOMS',
#  'SSWL',
#  'LT',
#  'SUNDARAM',
#  'SUNDRMFAST',
#  'LT',
#  'SWARAJENG',
#  'UCALFUEL',
#  'LT',
#  'LT',
#  'LT',
#  'APOLLOTYRE',
#  'BALKRISIND',
#  'LT',
#  'LT',
#  'GOODYEAR',
#  'TI',
#  'JKTYRE',
#  'LT',
#  'KESORAMIND',
#  'MODIRUBBER',
#  'LT',
#  'LT',
#  'LT',
#  'TI',
#  'LT',
#  'GMBREW',
#  'IFBAGRO',
#  'WEL',
#  'RADICO',
#  'TI',
#  'LT',
#  'ITI',
#  'UBL',
#  'VBL',
#  'SCI',
#  'BAGFILMS',
#  'ENIL',
#  'NDTV',
#  'NETWORK18',
#  'LT',
#  'IOC',
#  'RAJTV',
#  'SABTN',
#  'LT',
#  'LT',
#  'TVTODAY',
#  'LT',
#  'ZEEL',
#  'ZEEMEDIA',
#  'LT',
#  'LT',
#  'LT',
#  'TI',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'GREENPLY',
#  'LT',
#  'NH',
#  'KAJARIACER',
#  'LEXUS',
#  'CERA',
#  'ITC',
#  'LT',
#  'LT',
#  'CERA',
#  'LT',
#  'CERA',
#  'LT',
#  'LT',
#  'HATHWAY',
#  'LT',
#  'TI',
#  'LT',
#  'LT',
#  'LT',
#  'SCI',
#  'LT',
#  'SCI',
#  'AGI',
#  'LT',
#  'LT',
#  'BSHSL',
#  'DEEPAKFERT',
#  'LT',
#  'EIDPARRY',
#  'EXCELINDUS',
#  'FACT',
#  'GSFC',
#  'LT',
#  'INSECTICID',
#  'LT',
#  'LT',
#  'LT',
#  'TI',
#  'MANGCHEFER',
#  'LT',
#  'LT',
#  'LT',
#  'TI',
#  'LT',
#  'LT',
#  'PUNJABCHEM',
#  'LT',
#  'LT',
#  'RCF',
#  'LT',
#  'LT',
#  'SPIC',
#  'LT',
#  'TATACHEM',
#  'LT',
#  'ZUARI',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'AMBICAAGAR',
#  'LT',
#  'LT',
#  'CLNINDIA',
#  'SPECIALITY',
#  'FINEORG',
#  'FOSECOIND',
#  'LT',
#  'LT',
#  'TI',
#  'LT',
#  'CHEMCON',
#  'LT',
#  'VIKASECO',
#  'AGARIND',
#  'AKSHARCHEM',
#  'LT',
#  'ALKYLAMINE',
#  'ANDHRSUGAR',
#  'APCOTEXIND',
#  'LT',
#  'ASAHISONG',
#  'LT',
#  'BASF',
#  'LT',
#  'BHAGERIA',
#  'SCI',
#  'ACE',
#  'CHAMBLFERT',
#  'LT',
#  'CHEMFAB',
#  'LT',
#  'COROMANDEL',
#  'DCW',
#  'DEEPAKNTR',
#  'DHANUKA',
#  'LT',
#  'LT',
#  'LT',
#  'GNFC',
#  'LT',
#  'GRWRHITECH',
#  'GUJALKALI',
#  'LT',
#  'IGPL',
#  'INDIAGLYCO',
#  'LT',
#  'IOLCP',
#  'LT',
#  'JBFIND',
#  'LT',
#  'KANORICHEM',
#  'SCI',
#  'LT',
#  'KOTHARIPET',
#  'LT',
#  'LT',
#  'LT',
#  'MAHICKRA',
#  'MANALIPETC',
#  'LT',
#  'LT',
#  'NAVINFLUOR',
#  'NEOGEN',
#  'LT',
#  'LT',
#  'CCL',
#  'SPECIALITY',
#  'LT',
#  'PIIND',
#  'POLYPLEX',
#  'PREMEXPLN',
#  'PROLIFE',
#  'LT',
#  'LT',
#  'LT',
#  'SHK',
#  'SHK',
#  'SIGIND',
#  'SIL',
#  'OIL',
#  'LT',
#  'LT',
#  'SUDARSCHEM',
#  'LT',
#  'TIRUMALCHM',
#  'TNPETRO',
#  'LT',
#  'TI',
#  'LT',
#  'LT',
#  'VINATIORGA',
#  'LT',
#  'VISHNU',
#  'LT',
#  'VSCL',
#  'LT',
#  'LT',
#  'REFEX',
#  'SOUTHWEST',
#  'LT',
#  'LT',
#  'LT',
#  'EPL',
#  'LT',
#  'LT',
#  'KERNEX',
#  'RAIN',
#  'LT',
#  'LT',
#  'LT',
#  'RICHA',
#  'LT',
#  'LT',
#  'ACE',
#  'APCL',
#  'ARENTERP',
#  'AROGRANITE',
#  'TI',
#  'PNB',
#  'LT',
#  'BVCL',
#  'DECCANCE',
#  'GRASIM',
#  'GSCLCEMENT',
#  'HEIDELBERG',
#  'LT',
#  'LT',
#  'INDIACEM',
#  'LT',
#  'JKLAKSHMI',
#  'TI',
#  'MADHAV',
#  'MANGLMCEM',
#  'NCLIND',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'RAMCOCEM',
#  'RAMCOIND',
#  'SAGCEM',
#  'SANGHIIND',
#  'SHREDIGCEM',
#  'LT',
#  'LT',
#  'LT',
#  'VESUVIUS',
#  'LT',
#  'LT',
#  'WELSPUNIND',
#  'LT',
#  'AHIMSA',
#  'ARROWGREEN',
#  'ASTRON',
#  'LT',
#  'LT',
#  'DKEGL',
#  'EMMBI',
#  'LT',
#  'FLEXITUFF',
#  'ATGL',
#  'LT',
#  'LT',
#  'JINDALPOLY',
#  'LT',
#  'MAXVIL',
#  'NRAIL',
#  'LT',
#  'PEARLPOLY',
#  'LT',
#  'LT',
#  'SABAR',
#  'LT',
#  'LT',
#  'LT',
#  'HMT',
#  'LT',
#  'TIMETECHNO',
#  'LT',
#  'LT',
#  'LT',
#  'ABAN',
#  'JINDRILL',
#  'LT',
#  'BLS',
#  'CMRSL',
#  'LT',
#  'SHOPERSTOP',
#  'LT',
#  'ADANIGREEN',
#  'LT',
#  'ADANITRANS',
#  'AGNI',
#  'CESC',
#  'LT',
#  'LT',
#  'GIPCL',
#  'GREENPOWER',
#  'INDOWIND',
#  'JPPOWER',
#  'LT',
#  'TI',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'POWERGRID',
#  'LT',
#  'RELIANCE',
#  'RELIANCE',
#  'RTNPOWER',
#  'LT',
#  'LT',
#  'LT',
#  'TEXINFRA',
#  'TORNTPOWER',
#  'LT',
#  'AMARAJABAT',
#  'BBL',
#  'LT',
#  'BHAGYANGR',
#  'BHEL',
#  'LT',
#  'CGPOWER',
#  'CMICABLES',
#  'CORDSCABLE',
#  'LT',
#  'LT',
#  'ELECON',
#  'ESABINDIA',
#  'EVEREADY',
#  'FINCABLES',
#  'FOCUS',
#  'LT',
#  'LT',
#  'LT',
#  'HAVELLS',
#  'HBLPOWER',
#  'LT',
#  'HONDAPOWER',
#  'LT',
#  'INDOTECH',
#  'LT',
#  'KEC',
#  'KEI',
#  'OIL',
#  'LT',
#  'LT',
#  'PARACABLES',
#  'LT',
#  'PRECWIRE',
#  'LT',
#  'SALZERELEC',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'SWELECTES',
#  'ITC',
#  'TARAPUR',
#  'TDPOWERSYS',
#  'TNTELE',
#  'LT',
#  'LT',
#  'ITC',
#  'VGUARD',
#  'LT',
#  'LT',
#  'WSI',
#  'CENTUM',
#  'LT',
#  'UNIVCABLES',
#  'LT',
#  'DEN',
#  'GENUSPOWER',
#  'HONAUT',
#  'HPL',
#  'LT',
#  'POWERINDIA',
#  'SHIGAN',
#  'SPECTRUM',
#  'TVSELECT',
#  'LT',
#  'APOLLO',
#  'LT',
#  'DIXON',
#  'LT',
#  'LT',
#  'LT',
#  'NELCO',
#  'LT',
#  'LT',
#  'TI',
#  'DUCON',
#  'GSTL',
#  'KORE',
#  'OPTIEMUS',
#  'PALREDTEC',
#  'LT',
#  'BAJAJELEC',
#  'BUTTERFLY',
#  'LT',
#  'JCHAC',
#  'LT',
#  'LT',
#  'PULZ',
#  'LT',
#  'LT',
#  'WHIRLPOOL',
#  'A2ZINFRA',
#  'LT',
#  'LT',
#  'LT',
#  'ARSSINFRA',
#  'LT',
#  'LT',
#  'LT',
#  'BGRENERGY',
#  'BBL',
#  'BMETRICS',
#  'BRNL',
#  'ACI',
#  'CCL',
#  'IPL',
#  'LT',
#  'LT',
#  'ENGINERSIN',
#  'GAYAHWS',
#  'GAYAPROJ',
#  'LT',
#  'LT',
#  'GIRIRAJ',
#  'TI',
#  'RBA',
#  'TI',
#  'LT',
#  'GTLINFRA',
#  'GVKPIL',
#  'HCC',
#  'LT',
#  'HGINFRA',
#  'NSIL',
#  'IRB',
#  'IRCON',
#  'LT',
#  'ITDC',
#  'JKIL',
#  'JPINFRATEC',
#  'KALPATPOWR',
#  'HAL',
#  'KEC',
#  'KNRCON',
#  'LT',
#  'LSIL',
#  'LT',
#  'LT',
#  'MADHUCON',
#  'MANAV',
#  'MBECL',
#  'MBLINFRA',
#  'LT',
#  'TECHM',
#  'NILAINFRA',
#  'LT',
#  'LT',
#  'PATELENG',
#  'IGL',
#  'LT',
#  'POWERMECH',
#  'PRAJIND',
#  'LT',
#  'RAMKY',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'RPPINFRA',
#  'RVNL',
#  'SADBHAV',
#  'SADBHAV',
#  'SALASAR',
#  'LT',
#  'LT',
#  'LT',
#  'TI',
#  'SIMPLEXINF',
#  'SKIL',
#  'LT',
#  'LT',
#  'SSINFRA',
#  'SUPREMEINF',
#  'LT',
#  'TI',
#  'LT',
#  'TECHNOE',
#  'TRANSWIND',
#  'LT',
#  'VASCONEQ',
#  'VINDHYATEL',
#  'LT',
#  'LT',
#  'FEL',
#  'AAVAS',
#  'LT',
#  'LT',
#  'ARMANFIN',
#  'LT',
#  'AUBANK',
#  'LT',
#  'BAJFINANCE',
#  'NH',
#  'LT',
#  'CGCL',
#  'CHOLAFIN',
#  'CHOLAHLDNG',
#  'ACC',
#  'LT',
#  'DCM',
#  'LT',
#  'LT',
#  'GICHSGFIN',
#  'GLFL',
#  'HDFC',
#  'LT',
#  'HUDCO',
#  'IBULHSGFIN',
#  'LT',
#  'LT',
#  'LT',
#  'STAR',
#  'LT',
#  'IRFC',
#  'LICHSGFIN',
#  'INA',
#  'LT',
#  'MANAPPURAM',
#  'MASFIN',
#  'MUTHOOTCAP',
#  'LT',
#  'DRA',
#  'LT',
#  'PFC',
#  'PTC',
#  'PNB',
#  'LT',
#  'LT',
#  'LT',
#  'RELIANCE',
#  'SANGHVIMOV',
#  'TI',
#  'SBICARD',
#  'LT',
#  'LT',
#  'SREINFRA',
#  'LT',
#  'SUNDARMFIN',
#  'TARACHAND',
#  'LT',
#  'LT',
#  'LT',
#  'UJJIVAN',
#  'LT',
#  'LT',
#  'BAJAJHLDNG',
#  'LT',
#  'BBL',
#  'CONSOFINVT',
#  'CREST',
#  'DHUNINV',
#  'LT',
#  'ITI',
#  'NH',
#  'IDI',
#  'LT',
#  'KICL',
#  'LFIC',
#  'MASKINVEST',
#  'NBIFIN',
#  'NDGL',
#  'NSIL',
#  'ONELIFECAP',
#  'PILANIINVS',
#  'LT',
#  'SILINV',
#  'LT',
#  'SUNDARMHLD',
#  'TI',
#  'VHL',
#  'LT',
#  'WELENT',
#  'WILLAMAGOR',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'TCI',
#  'LT',
#  'LT',
#  'SPENCERS',
#  'BBTC',
#  'LT',
#  'DVL',
#  'SGIL',
#  'GROBTEA',
#  'NESTLEIND',
#  'VIKASWSP',
#  'LT',
#  'APEX',
#  'LT',
#  'HATSUN',
#  'LT',
#  'PARAGMILK',
#  'LT',
#  'UMANGDAIRY',
#  'LT',
#  'ADVENZYMES',
#  'ANNAPURNA',
#  'AVTNPL',
#  'LT',
#  'LT',
#  'BRITANNIA',
#  'CCL',
#  'LT',
#  'DFMFOODS',
#  'LT',
#  'DYNPRO',
#  'LT',
#  'LT',
#  'GAEL',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'MCLEODRUSS',
#  'LT',
#  'NORBTEAEXP',
#  'ITI',
#  'LT',
#  'TAPIFRUIT',
#  'TASTYBITE',
#  'LT',
#  'UNITEDTEA',
#  'VADILALIND',
#  'LT',
#  'LT',
#  'TI',
#  'GREENLAM',
#  'LT',
#  'LT',
#  'PREMIERPOL',
#  'RESPONIND',
#  'LT',
#  'LT',
#  'LT',
#  'ATGL',
#  'LT',
#  'GSPL',
#  'LT',
#  'HAVISHA',
#  'IGL',
#  'LT',
#  'PETRONET',
#  'AMJUMBO',
#  'ASAHIINDIA',
#  'LT',
#  'LT',
#  'BINANIIND',
#  'LT',
#  'CERA',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'PRESTIGE',
#  'SHANKARA',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'PRAENG',
#  'LT',
#  'APOLLOHOSP',
#  'ARTEMISMED',
#  'LT',
#  'LT',
#  'LT',
#  'INDRAMEDCO',
#  'KIMS',
#  'KOVAI',
#  'LT',
#  'LT',
#  'NH',
#  'RAINBOW',
#  'LT',
#  'ADVANIHOTR',
#  'AHL',
#  'NH',
#  'NH',
#  'BYKE',
#  'LT',
#  'EIHAHOTELS',
#  'LT',
#  'LT',
#  'INDHOTEL',
#  'ITDC',
#  'KAMATHOTEL',
#  'LEMONTREE',
#  'ORIENTHOT',
#  'LT',
#  'TAJGVK',
#  'TGBHOTELS',
#  'LT',
#  'BAJAJCON',
#  'COLPAL',
#  'LT',
#  'LT',
#  'LT',
#  'FACT',
#  'LT',
#  'GODREJCP',
#  'HINDUNILVR',
#  'JHS',
#  'LT',
#  'LT',
#  'LT',
#  'PGHH',
#  'LT',
#  'BALMLAWRIE',
#  'LT',
#  'LT',
#  'JPASSOCIAT',
#  'LT',
#  'LT',
#  'LT',
#  'UNIENTER',
#  'AIAENG',
#  'AMBER',
#  'PRECISION',
#  'LT',
#  'ANUP',
#  'BANCOINDIA',
#  'LT',
#  'LT',
#  'BLUESTARCO',
#  'CROMPTON',
#  'TI',
#  'EKC',
#  'LT',
#  'EMKAYTOOLS',
#  'FMGOETZE',
#  'LT',
#  'HERCULES',
#  'LT',
#  'LT',
#  'LT',
#  'LT',
#  'INDIANCARD',
#  'LT',
#  'LT',
#  'KABRAEXTRU',
#  ...]

# %%
for i in range(0,len(arr_indus)):
  if str("20MICRONS") in str(arr_indus[i]):
    print(arr_indus[i])
# Out:
# 220MICRONS20 MICRONS LTD

# %%
ll = getMatch(final_list , arr_indus )

# %%
ll.sort
print(len(set(ll)))
# Out:
# 797

# %%
# !git clone https://github.com/yashalgo/code.git
# Out:
# Cloning into 'code'...
# fatal: could not read Username for 'https://github.com': No such device or address
